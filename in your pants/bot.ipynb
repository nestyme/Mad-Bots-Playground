# %%
token='807872051:AAGaedVqrwtwVfKRgwygTzwGTSsOh3JVjGU'
import telebot
from PIL import Image, ImageDraw, ImageFont
from urllib.request import urlretrieve
import os
import random
import telebot
from telebot import apihelper
from PIL import Image
import cv2
import numpy as np
import requests
session = requests.Session()
i = 0

def download_picture(text):
    os.system('python downloader.py -s {} -o pics --limit 1'.format(text.replace(' ', '+')))
    
def get_picture(text):
    response = session.get(
                'http://api.duckduckgo.com/',
                params={
                    'q': text,
                    'format': 'json'
                }
            ).json()
    image_url = response.get('Image')
    urlretrieve(image_url, 'img.jpeg')    
    
def put_into_pants(text):
    try:
        get_picture(text)
        print('dick api')
    except:
        download_picture(text)
        print('bing api')
    download_picture(text)
    text=text.upper()
    print(text)
    back = Image.open('jeans.png').resize((512,512))
    # background = Image.new('RGBA', size=(512,512))
    front = Image.open('pics/img.png', 'r').resize((160,160))
    back.paste(front, (175,5))
    # background.paste(back,(0,0))
    fnt = ImageFont.truetype('/Library/Fonts/Impact.ttf', 30)
    d = ImageDraw.Draw(back)
    d.text((100,420), "    {}\n    У ТЕБЯ В ШТАНАХ".format(text.upper()), font=fnt, fill=(0, 0, 0))
    name = 'stickers/curr{}.png'.format(random.randint(0,400))
    back.save('result.png', format='png')
    os.system('rm -r pics/*')
    
def break_if_too_long(string, widthsize = 38):
    if len(string) > widthsize*2:
        string = string[:38]+'\n         '+string[38:76]+'\n         '+string[76:]
        return string
    if len(string) > widthsize:
        string = string[:38]+'\n         '+string[38:]
    return string
def cut_into_sticker(path):
    basewidth = 512
    img = Image.open(path)
    wpercent = (basewidth/float(img.size[0]))
    hsize = int((float(img.size[1])*float(wpercent)))
    img = img.resize((basewidth,hsize), Image.ANTIALIAS)
    if img.size[1] > 512:
        img=img.crop((0,0,512,512))
    print(img.size)
    img.save(path) 

def delete_background(path):
    print('running')
    os.system('python3 /Users/n.zueva/Desktop/image-background-removal/seg.py \
    {} {} 1'.format(path, path))
    
bot = telebot.TeleBot(token)
@bot.message_handler(content_types=["text", "photo"])
def handle(message, i=0): 
    # print(message)
    try:
        print('direct recieved')
        i += 1
        text = message.text.split(' ')[0]
        
        bot.send_photo(chat_id=message.chat.id, photo=open(name, 'rb'))
    except:
        try:
            print('photo recieved')
            file_path = bot.get_file(message.photo[1].file_id).file_path
            link = 'https://api.telegram.org/file/bot{}/{}'.format(token, file_path)
            tmp_name = '{}{}.png'.format('file_' + message.from_user.first_name,random.randint(24,42))
            urlretrieve(link, tmp_name)
            print('saved at {}'.format(tmp_name))
            delete_background(tmp_name)
            cut_into_sticker(tmp_name)
            print('alalala')
            bot.send_photo(chat_id=message.chat.id, photo=open(tmp_name, 'r'))
        except:
            try:
                print('direct recieved')
                i += 1
                print('-'*80)
                print(message.from_user)
                text = message.text
                put_into_pants(text)
                bot.send_photo(chat_id=message.chat.id, photo=open('result.png', 'rb'))
            except:
                bot.send_message(chat_id=message.chat.id, text = 'я не буду конвертить это дерьмо')

# %%
import requests
session = requests.Session()

# %%
def get_picture(text):
    response = session.get(
                'http://api.duckduckgo.com/',
                params={
                    'q': text,
                    'format': 'json'
                }
            ).json()
    image_url = response.get('Image')
    urlretrieve(image_url, 'img.jpeg')

# %%
get_picture('утка')

# %%
if __name__ == '__main__':
    bot.polling(none_stop=True,  timeout=123)
# Out:
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 284107682, 'is_bot': False, 'first_name': 'Sofia', 'username': 'SofiaZueva', 'last_name': 'Zueva', 'language_code': 'en'}
# bing api
# ВЫХОДИ
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 284107682, 'is_bot': False, 'first_name': 'Sofia', 'username': 'SofiaZueva', 'last_name': 'Zueva', 'language_code': 'en'}
# bing api
# ТЫ ГДЕ
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# МАГА
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# МАГИСТРАТУРА
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# ПОТОМ ОТКОНВЕРТИШЬ КРЧ
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 204442584, 'is_bot': False, 'first_name': 'Mila', 'username': 'Rvanova', 'last_name': 'Rvánova', 'language_code': 'ru'}
# bing api
# ШАРЫ
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 204442584, 'is_bot': False, 'first_name': 'Mila', 'username': 'Rvanova', 'last_name': 'Rvánova', 'language_code': 'ru'}
# bing api
# /START
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# ФИВТ
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# ФКН
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 204442584, 'is_bot': False, 'first_name': 'Mila', 'username': 'Rvanova', 'last_name': 'Rvánova', 'language_code': 'ru'}
# bing api
# ПРИЕМКА
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# ВЫШКА
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# dick api
# ВШЭ
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# PYTHON
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# А ПОЧЕМУ
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# МАШИННОЕ ОБУЧЕНИЕ
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# МАШИННОЕ ОБУЧЕНИЕ
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# А ТО ЕСТЬ ПИКЧА ОДНА И ТА ЖЕ ОКК
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# АХХАХА
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# ЯНДЕК
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# БЛЯТЬ ЯНДЕКС
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# dick api
# ЯНДЕКС
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# ЗУЕВА НАДЕЖДА НИКОЛАЕВНА
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# НЕ БАНЬТЕ)0
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# ТАРАКАН
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# ФУ НАХУЙ
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# dick api
# ШТАНЫ
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# LARGE SODA
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# HTTPS://T.ME/YLPTRED_CODES
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# СУКА)
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# YLPTRED
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# ПАВЕЛ ДУРОВ
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# SHIT
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# ПОСТИРОНИЯ
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 161522272, 'is_bot': False, 'first_name': 'YLPTRED', 'username': 'YLPTRED', 'last_name': None, 'language_code': 'ru'}
# bing api
# СОСМЫСЛОМ
# direct recieved
# photo recieved
# direct recieved
# --------------------------------------------------------------------------------
# {'id': 148126240, 'is_bot': False, 'first_name': 'Надя', 'username': 'Nestyme', 'last_name': 'Зуева', 'language_code': 'ru'}
# bing api
# ОК
# 2019-07-05 21:13:13,894 (util.py:65 PollingThread) ERROR - TeleBot: "ReadTimeout occurred, args=(ReadTimeoutError("HTTPSConnectionPool(host='api.telegram.org', port=443): Read timed out. (read timeout=133)",),)
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py", line 385, in _make_request
#     httplib_response = conn.getresponse(buffering=True)
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py", line 387, in _make_request
#     httplib_response = conn.getresponse()
#   File "/anaconda3/lib/python3.6/http/client.py", line 1331, in getresponse
#     response.begin()
#   File "/anaconda3/lib/python3.6/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/anaconda3/lib/python3.6/http/client.py", line 258, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/anaconda3/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
#   File "/anaconda3/lib/python3.6/ssl.py", line 1012, in recv_into
#     return self.read(nbytes, buffer)
#   File "/anaconda3/lib/python3.6/ssl.py", line 874, in read
#     return self._sslobj.read(len, buffer)
#   File "/anaconda3/lib/python3.6/ssl.py", line 631, in read
#     v = self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 403, in send
#     timeout=timeout
#   File "/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py", line 623, in urlopen
#     _stacktrace=sys.exc_info()[2])
#   File "/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/util/retry.py", line 255, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#   File "/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/packages/six.py", line 310, in reraise
#     raise value
#   File "/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py", line 578, in urlopen
#     chunked=chunked)
#   File "/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py", line 389, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py", line 314, in _raise_timeout
#     raise ReadTimeoutError(self, url, "Read timed out. (read timeout=%s)" % timeout_value)
# requests.packages.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='api.telegram.org', port=443): Read timed out. (read timeout=133)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/telebot/util.py", line 59, in run
#     task(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/telebot/__init__.py", line 276, in __retrieve_updates
#     updates = self.get_updates(offset=(self.last_update_id + 1), timeout=timeout)
#   File "/anaconda3/lib/python3.6/site-packages/telebot/__init__.py", line 246, in get_updates
#     json_updates = apihelper.get_updates(self.token, offset, limit, timeout, allowed_updates)
#   File "/anaconda3/lib/python3.6/site-packages/telebot/apihelper.py", line 180, in get_updates
#     return _make_request(token, method_url, params=payload)
#   File "/anaconda3/lib/python3.6/site-packages/telebot/apihelper.py", line 54, in _make_request
#     timeout=(connect_timeout, read_timeout), proxies=proxy)
#   File "/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 475, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/requests/sessions.py", line 585, in send
#     r = adapter.send(request, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/requests/adapters.py", line 479, in send
#     raise ReadTimeout(e, request=request)
# requests.exceptions.ReadTimeout: HTTPSConnectionPool(host='api.telegram.org', port=443): Read timed out. (read timeout=133)
# "
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384             try:  # Python 2.7, use buffering of HTTP responses
# --> 385                 httplib_response = conn.getresponse(buffering=True)
#     386             except TypeError:  # Python 2.6 and older
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386             except TypeError:  # Python 2.6 and older
# --> 387                 httplib_response = conn.getresponse()
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# /anaconda3/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# /anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# /anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#
# /anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#
# /anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     402                     retries=self.max_retries,
# --> 403                     timeout=timeout
#     404                 )
#
# /anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     622             retries = retries.increment(method, url, error=e, _pool=self,
# --> 623                                         _stacktrace=sys.exc_info()[2])
#     624             retries.sleep()
#
# /anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     254             if read is False:
# --> 255                 raise six.reraise(type(error), error, _stacktrace)
#     256             elif read is not None:
#
# /anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     309             raise value.with_traceback(tb)
# --> 310         raise value
#     311
#
# /anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     577                                                   body=body, headers=headers,
# --> 578                                                   chunked=chunked)
#     579
#
# /anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 389             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     390             raise
#
# /anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     313         if isinstance(err, SocketTimeout):
# --> 314             raise ReadTimeoutError(self, url, "Read timed out. (read timeout=%s)" % timeout_value)
#     315
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.telegram.org', port=443): Read timed out. (read timeout=133)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-9-ca7a20f364b3> in <module>
#       1 if __name__ == '__main__':
# ----> 2     bot.polling(none_stop=True,  timeout=123)
#
# /anaconda3/lib/python3.6/site-packages/telebot/__init__.py in polling(self, none_stop, interval, timeout)
#     387         """
#     388         if self.threaded:
# --> 389             self.__threaded_polling(none_stop, interval, timeout)
#     390         else:
#     391             self.__non_threaded_polling(none_stop, interval, timeout)
#
# /anaconda3/lib/python3.6/site-packages/telebot/__init__.py in __threaded_polling(self, none_stop, interval, timeout)
#     410                 or_event.wait()  # wait for polling thread finish, polling thread error or thread pool error
#     411
# --> 412                 polling_thread.raise_exceptions()
#     413                 self.worker_pool.raise_exceptions()
#     414
#
# /anaconda3/lib/python3.6/site-packages/telebot/util.py in raise_exceptions(self)
#      76         def raise_exceptions(self):
#      77             if self.exception_event.is_set():
# ---> 78                 six.reraise(self.exc_info[0], self.exc_info[1], self.exc_info[2])
#      79
#      80         def clear_exceptions(self):
#
# /anaconda3/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /anaconda3/lib/python3.6/site-packages/telebot/util.py in run(self)
#      57                     self.received_task_event.set()
#      58
# ---> 59                     task(*args, **kwargs)
#      60                     logger.debug("Task complete")
#      61                     self.done_event.set()
#
# /anaconda3/lib/python3.6/site-packages/telebot/__init__.py in __retrieve_updates(self, timeout)
#     274             logger.debug('Skipped {0} pending messages'.format(self.__skip_updates()))
#     275             self.skip_pending = False
# --> 276         updates = self.get_updates(offset=(self.last_update_id + 1), timeout=timeout)
#     277         self.process_new_updates(updates)
#     278
#
# /anaconda3/lib/python3.6/site-packages/telebot/__init__.py in get_updates(self, offset, limit, timeout, allowed_updates)
#     244         :return: array of Updates
#     245         """
# --> 246         json_updates = apihelper.get_updates(self.token, offset, limit, timeout, allowed_updates)
#     247         ret = []
#     248         for ju in json_updates:
#
# /anaconda3/lib/python3.6/site-packages/telebot/apihelper.py in get_updates(token, offset, limit, timeout, allowed_updates)
#     178     if allowed_updates:
#     179         payload['allowed_updates'] = json.dumps(allowed_updates)
# --> 180     return _make_request(token, method_url, params=payload)
#     181
#     182
#
# /anaconda3/lib/python3.6/site-packages/telebot/apihelper.py in _make_request(token, method_name, method, params, files, base_url)
#      52         if 'connect-timeout' in params: connect_timeout = params['connect-timeout'] + 10
#      53     result = _get_req_session().request(method, request_url, params=params, files=files,
# ---> 54                                         timeout=(connect_timeout, read_timeout), proxies=proxy)
#      55     logger.debug("The server returned: '{0}'".format(result.text.encode('utf8')))
#      56     return _check_result(method_name, result)['result']
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     583
#     584         # Send the request
# --> 585         r = adapter.send(request, **kwargs)
#     586
#     587         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     477                 raise SSLError(e, request=request)
#     478             elif isinstance(e, ReadTimeoutError):
# --> 479                 raise ReadTimeout(e, request=request)
#     480             else:
#     481                 raise
#
# ReadTimeout: HTTPSConnectionPool(host='api.telegram.org', port=443): Read timed out. (read timeout=133)

# %%
put_into_pants('утка')

# %%
import urllib.request
import simplejson

fetcher = urllib.request.build_opener()
searchTerm = 'parrot'
startIndex = 0
searchUrl = "http://ajax.googleapis.com/ajax/services/search/images?v=1.0&q=" + searchTerm + "&start=" + startIndex
f = fetcher.open(searchUrl)
deserialized_output = simplejson.load(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-9a4a5af4d485> in <module>
#       5 searchTerm = 'parrot'
#       6 startIndex = 0
# ----> 7 searchUrl = "http://ajax.googleapis.com/ajax/services/search/images?v=1.0&q=" + searchTerm + "&start=" + startIndex
#       8 f = fetcher.open(searchUrl)
#       9 deserialized_output = simplejson.load(f)
#
# TypeError: must be str, not int

# %%
from selenium import webdriver
import urllib
from selenium.webdriver.common.keys import Keys
driver = webdriver.Chrome('C:/Python35/Scripts/chromedriver.exe')
word="apple"
url="http://images.google.com/search?q="+word+"&tbm=isch&sout=1"
driver.get(url)
imageXpathSelector='//*[@id="ires"]/table/tbody/tr[1]/td[1]/a/img'
img=driver.find_element_by_xpath(imageXpathSelector)
src=(img.get_attribute('src'))
urllib.urlretrieve(src, word+".jpg")
driver.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# /anaconda3/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#
# /anaconda3/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1363                             err_msg += ': ' + repr(err_filename)
# -> 1364                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1365                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Python35/Scripts/chromedriver.exe': 'C:/Python35/Scripts/chromedriver.exe'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-10-8ac133e1f3b4> in <module>
#       2 import urllib
#       3 from selenium.webdriver.common.keys import Keys
# ----> 4 driver = webdriver.Chrome('C:/Python35/Scripts/chromedriver.exe')
#       5 word="apple"
#       6 url="http://images.google.com/search?q="+word+"&tbm=isch&sout=1"
#
# /anaconda3/lib/python3.6/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# /anaconda3/lib/python3.6/site-packages/selenium/webdriver/common/service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'chromedriver.exe' executable needs to be in PATH. Please see https://sites.google.com/a/chromium.org/chromedriver/home

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#     100% |████████████████████████████████| 911kB 6.9MB/s ta 0:00:01
# Requirement already satisfied: urllib3 in /anaconda3/lib/python3.6/site-packages (from selenium) (1.22)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
import downloader
import os
def download_picture(text):
    os.system('python downloader.py -s {} -o pics --limit 1'.format(text.replace(' ', '+')))
# Out:
# 0

# %%
deserialized_output
# Out:
# {'responseData': None,
#  'responseDetails': 'This API is no longer available.',
#  'responseStatus': 403}

# %%
imageUrl = deserialized_output['responseData']['results'][0]['unescapedUrl']
file = StringIO(urllib.urlopen(imageUrl).read())
img = Image.open(file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-63ef5219c90f> in <module>
# ----> 1 imageUrl = deserialized_output['responseData']['results'][0]['unescapedUrl']
#       2 file = urllib.urlopen(imageUrl).read()
#       3 img = Image.open(file)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
from io import StringIO

# %%
def put_into_pants(text):
    download_picture(text)
    text=text.upper()
    print(text)
    back = Image.open('jeans.png').resize((512,512))
    # background = Image.new('RGBA', size=(512,512))
    front = Image.open('pics/img.png', 'r').resize((160,160))
    back.paste(front, (175,5))
    # background.paste(back,(0,0))
    fnt = ImageFont.truetype('/Library/Fonts/Impact.ttf', 30)
    d = ImageDraw.Draw(back)
    d.text((100,420), "    {}\n    У ТЕБЯ В ШТАНАХ".format(text.upper()), font=fnt, fill=(0, 0, 0))
    name = 'stickers/curr{}.png'.format(random.randint(0,400))
    back.save('result.png', format='png')
    os.system('rm -r pics/*')

# %%
put_into_pants('синий кит')
# Out:
# СИНИЙ КИТ
